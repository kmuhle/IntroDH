# %%
from pathlib import Path

paus_filename = Path("./txt/tlg0525.tlg001.theoi-eng.txt")

with open(paus_filename) as f:
    book_1 = f.read()

# %%
book_1[100:200]
# Out:
# 'e Sunium promontory stands out from the Attic land. When you have rounded the promontory you see a h'

# %%
# %pip install spacy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run -m spacy download en_core_web_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 46.4 MB/s eta 0:00:0000:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
from spacy import displacy

# Load the model that we downloaded.
# If this line fails, make sure that
# you have downloaded the model that's
# referenced here.
nlp = spacy.load("en_core_web_md")

# Analyze `book_1` — this might take a bit.
doc = nlp(book_1)

# %%
# We're running these lines in a separate cell so that we don't
# need to run the full analysis each time we inspect the results.

ents = [(e.text, e.label_) for e in doc.ents]

for ent in ents:
    print(ent)
# Out:
# ('SUNIUM & LAURIUM', 'ORG')
# ('1.1.1', 'CARDINAL')
# ('I.', 'PERSON')
# ('Greek', 'NORP')
# ('the Cyclades Islands', 'LOC')
# ('the Aegean Sea', 'LOC')
# ('Sunium', 'LOC')
# ('Attic', 'NORP')
# ('Athena of Sunium', 'ORG')
# ('Laurium', 'PERSON')
# ('Athenians', 'NORP')
# ('the Island of Patroclus', 'LOC')
# ('Patroclus', 'ORG')
# ('Egyptian', 'NORP')
# ('Ptolemy', 'PERSON')
# ('Ptolemy', 'GPE')
# ('Lagus', 'PERSON')
# ('Athenians', 'NORP')
# ('Antigonus', 'LOC')
# ('Demetrius', 'PERSON')
# ('PEIRAEUS', 'ORG')
# ('1.1.2', 'CARDINAL')
# ('Peiraeus', 'PERSON')
# ('Themistocles', 'ORG')
# ('Phalerum', 'GPE')
# ('Athens', 'GPE')
# ('Menestheus', 'PERSON')
# ('Troy', 'PERSON')
# ('Theseus', 'PERSON')
# ('Minos', 'ORG')
# ('Androgeos', 'ORG')
# ('Themistocles', 'ORG')
# ('Peiraeus', 'PERSON')
# ('three', 'CARDINAL')
# ('Phalerum', 'GPE')
# ('Athenian', 'NORP')
# ('Themistocles', 'ORG')
# ('Athenians', 'NORP')
# ('Themistocles', 'ORG')
# ('Magnesia', 'LOC')
# ('Themistocles', 'ORG')
# ...

# %%
unique_labels = set(label for (text, label) in ents)

print(unique_labels)
# Out:
# {'PRODUCT', 'QUANTITY', 'LAW', 'EVENT', 'TIME', 'PERSON', 'DATE', 'GPE', 'ORDINAL', 'ORG', 'CARDINAL', 'WORK_OF_ART', 'FAC', 'NORP', 'LOC', 'LANGUAGE'}

# %%
loc_ents = [ent for ent in ents if ent[1] == 'LOC']

print(len(loc_ents))
# Out:
# 124

# %%
from collections import Counter

loc_ent_counts = Counter(loc_ents)

# Print counts
for (text, label), count in loc_ent_counts.items():
    print(f"{text} ({label}): {count}")
# Out:
# the Cyclades Islands (LOC): 1
# the Aegean Sea (LOC): 1
# Sunium (LOC): 2
# the Island of Patroclus (LOC): 2
# Antigonus (LOC): 26
# Magnesia (LOC): 1
# Thermodon (LOC): 1
# Melpomenus (LOC): 1
# Earth (LOC): 9
# Phaethon (LOC): 1
# Europe (LOC): 3
# the Ionian Sea (LOC): 2
# the Lamian gulf (LOC): 1
# Asia (LOC): 14
# Pessinus (LOC): 1
# Meda (LOC): 1
# Pandion (LOC): 5
# Acropolis (LOC): 11
# Cestrinus (LOC): 2
# Mercy (LOC): 1
# the Olympian Zeus (LOC): 1
# Acherusia (LOC): 1
# The Gardens (LOC): 1
# Gardens (LOC): 1
# Eridanus (LOC): 2
# the North Wind (LOC): 2
# ASIA (LOC): 1
# South (LOC): 1
# the Athenian Acropolis (LOC): 3
# Epicharinus (LOC): 1
# Mount Sipylus (LOC): 1
# Io (LOC): 2
# the Greek Sea (LOC): 1
# Marathon (LOC): 1
# Anteros (LOC): 1
# the Red Sea (LOC): 1
# Nile (LOC): 4
# Atlantes (LOC): 1
# Mount Atlas (LOC): 1
# Chalcinus (LOC): 1
# Ceryx (LOC): 1
# Cithaeron (LOC): 3
# Eteocles (LOC): 1
# Theocosmus (LOC): 2
# Echemus (LOC): 1
# Mount Gerania (LOC): 1
# ...

# %%
import pandas as pd
df = pd.DataFrame([(text, label, count) for (text, label), count in loc_ent_counts.items()], columns=['Text', 'Label', 'Count'])

# df.to_csv('Periegesis.csv', index=False)
